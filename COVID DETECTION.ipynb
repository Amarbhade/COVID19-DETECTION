# %% [markdown]
# # IMPORT REQUIRED LIBRARIES

# %%
import os

# %%
import pandas as pd

# %%
import numpy as np

# %%
import cv2

# %%
import warnings as wr
wr.filterwarnings("ignore")

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # LOAD DATASET

# %%
path=r"C:\Users\ADMIN\Documents\DEEP LEARNING\COVID\NEGATIVE"

# %%
categories=["NEGATIVE","POSITIVE"]

# %%
path1=r"C:\Users\ADMIN\Documents\DEEP LEARNING\COVID\POSITIVE"

# %%
negative=[]
for i in range(1,1583):
    q=os.path.join(path,"nega ({}).jpeg".format(i))
    q=cv2.imread(q)
    q=cv2.resize(q,(100,100))
    negative.append([q,0])

# %%
plt.imshow(negative[5][0])

# %%
positive=[]
for i in range(1,4265):
    p=os.path.join(path1,"posi ({}).jpeg".format(i))
    p=cv2.imread(p)
    p=cv2.resize(p,(100,100))
    positive.append([p,1])

# %%
plt.imshow(positive[5][0])

# %%
w=os.path.join(path1,"posi (6).jpeg")
w=cv2.imread(w)
w=cv2.resize(w,(100,100))
plt.imshow(w)

# %%
w==positive[5][0]
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
# ...

# %%
data=negative+positive

# %%
import random

# %%
random.shuffle(data)

# %%
x=[]
y=[]

for i in data:
    x.append(i[0])
    y.append(i[1])

# %%
plt.imshow(x[3])

# %%
y[3]
# Out:
# 1

# %% [markdown]
# # CREATING MODEL

# %%
from keras.layers import *

# %%
from keras.models import Sequential

# %%
model=Sequential()

# %%
model.add(Conv2D(64,(3,3),input_shape=(100,100,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(128,activation="relu"))
model.add(Dense(1,activation="sigmoid"))

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 98, 98, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 128)               8320
#
# ...

# %%
A=np.array(x)/255

# %%
B=np.array(y)

# %%
model.fit(A,B,batch_size=100,epochs=15,verbose=1)
# Out:
# Epoch 1/15
# 59/59 [==============================] - 82s 1s/step - loss: 0.2384 - accuracy: 0.9004
# Epoch 2/15
# 59/59 [==============================] - 86s 1s/step - loss: 0.1761 - accuracy: 0.9324
# Epoch 3/15
# 59/59 [==============================] - 86s 1s/step - loss: 0.1567 - accuracy: 0.9388
# Epoch 4/15
# 59/59 [==============================] - 86s 1s/step - loss: 0.1338 - accuracy: 0.9497
# Epoch 5/15
# 59/59 [==============================] - 88s 1s/step - loss: 0.1258 - accuracy: 0.9559
# Epoch 6/15
# 59/59 [==============================] - 98s 2s/step - loss: 0.1131 - accuracy: 0.9577
# Epoch 7/15
# 59/59 [==============================] - 91s 2s/step - loss: 0.1209 - accuracy: 0.9516
# Epoch 8/15
# 59/59 [==============================] - 86s 1s/step - loss: 0.1026 - accuracy: 0.9627
# Epoch 9/15
# 59/59 [==============================] - 88s 1s/step - loss: 0.0903 - accuracy: 0.9666
# Epoch 10/15
# ...

# %%
from keras.utils.vis_utils import plot_model

# %%
plot_model(model)

# %% [markdown]
# # MODEL PREDICTION

# %%
T=r"C:\Users\ADMIN\Documents\DEEP LEARNING"

# %%
T=os.path.join(T,"download.jfif")

# %%
T=os.path.join(T,"download.jfif")
T=cv2.imread(T)
T=cv2.resize(T,(100,100))
plt.imshow(T)

# %%
model.predict(T.reshape(1,100,100,3))[0][0].round()
# Out:
# 1.0
